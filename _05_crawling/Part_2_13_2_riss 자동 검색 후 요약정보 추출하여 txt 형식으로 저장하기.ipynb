# %%
#Chap 13. riss.kr 사이트에서 특정 키워드로 자동 검색하기

#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time          

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 해양자원): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://www.riss.kr/'
driver.get(url)
time.sleep(5)
driver.maximize_window()

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")

#Step 5.학위 논문 선택하기
driver.find_element(By.LINK_TEXT,'학위논문').click() # 링크, 하이퍼링크(메뉴)를 누를 때 사용
time.sleep(2)

#Step 6.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('div','srchResultListW').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

#Step 7. 표준 출력 방향을 바꾸어 txt 파일에 저장하기
import sys 
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\riss.txt): ')

orig_stdout = sys.stdout
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file  #모니터에 출력하지 말고 file 에 출력해라

for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()    
sys.stdout = orig_stdout  #원래대로 변경 - 다시 화면에 출력시켜라    

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)
# Out:
# ====================================================================================================
#  이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.
# ====================================================================================================
#
#
#  앞으로 메타버스(Metaverse)가 게임이 주도하고, 연예인들이 공연하고 경제의 부가가치를 창출하는 곳으로만 인식되고 발전되어가는 전유물이 아니라 교회의 예배와 설교도 함께 나란히 맥을 이어 나가야 한다. 나아가 비대면의 시대와 대면의 시대를 공존할 수 있는 메타버스(Metaverse) 세계를 통해 다음 세대들과 가나안 성도들과 또한 노년층을 사는 앞선 세대들에게 복음을 전하고 양육할 수 있어야 한다. 따라서 비대면의 시대에 가상공간인 메타버스(Metaverse)를 살아갈 성도들의 예배를 위한 메타버스(Metaverse) 가상공간에 펼쳐지는 4가지 설교 방법을 대안으로 제시하고자 한다. 세대의 교회가 나타날 수 있다는 의미로 해석할 수 있다., 웹킨즈(Webkinz), 데어닷컴(There.com)등 다수의 가상세계(Virtual Worlds) 서비스를 출시했다. 이로 인해 다양한 메타버스(Metaverse)가 출현하고 상호 연결되는 거대한 가상세계(Virtual Worlds)인 '다중 가상세계(Virtual Worlds)' 또는 '멀티버스'(Multiverse)의 시대의 도래가 가까워졌다.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
#  This study is significant in that it extends the scope of metaverse-related research by identifying the relationships between brand experience, consumer brand engagement, and brand loyalty and the influence of brand authenticity— areas where recent metaverse research is lacking. Furthermore, this study provides practical implications for companies regarding future metaverse utilization strategies to convey brand values or messages to consumers through brand experience amid the rapid growth in the digital media environment.nt, and 2. consumer brand engagement and brand loyalty. However, it has a moderated mediating effect on the relationships between brand experience in the metaverse, consumer brand engagement, and brand loyalty. This indicates that the greater the level of brand authenticity, the stronger the impact of brand experience in the metaverse on brand loyalty through consumer brand engagement. In particular, among the factors of brand experience in the metaverse, both entertainment and escapist experiences  have significant positive effects on consumer brand engagement and brand loyalty, with the escapist experience factor having a larger impact. Therefore, when brand communication is conducted through the metaverse, it is expected that the consumer–brand interaction will be higher and brand loyalty will be strengthened by implementing the unique worldview and functions of the metaverse, which are different from the real world and include entertainment elements.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
#  또 어느 기관이 신규 및 계속 과제를 진행하고 있는지 파악할 수 있고, 향후 R&D 예산을 어느 기관이나 분야에 더 투자해야 하는지 방향성을 정하는데 적절한 나침반이 될 것으로 전망된다.서 향후 메타버스 R&D 수행시 가이드 라인으로 사용할 수 있을 것으로 예상된다. 실제 정부가 메타버스 R&D 정책을 수행하는 과정에서  메타버스 기술 인력 양성을 위해 어떤 분야의 기술에 투자를 할 것인지 파악하고 활용하는 데 도움이 될 것으로 보인다.분석 방법인 텍스트마이닝과 네트워크 분석을 활용해서 현황 분석을 하였다.
#
#
# 원문보기
#
#
# 음성듣기
#
#
#  In addition, effort expectancy, social influence, price value, and telepresence did not have a statistically significant effect on the continuous purchase intention of virtual luxury brand products. Self-monitoring had no direct and moderating effect on the continuous purchase intention for virtual luxury brand products. Finally, Metaverse platform users' intention to continue purchasing virtual luxury brand products positively influenced their intention to purchase physical luxury brand products. 제품의 구 매의도에 이어지는지에 대한 실증적으로 탐구하였다. 설문조사는 메타버스 플랫폼에서 가상 럭셔리 브랜드 제품을 구매경험을 있는 사용자를 대상으로 온라인 설문조사 를 실시하였다. 연구 결과는 성과기대, 촉진조건, 쾌락적 동기, 자아 현존감, 독특성 추구 동기, 과시 추구 동기가 가상 럭셔리 브랜드 제품의 지속적 구매의도에 통계적으로 유의미 한 영향을 미치는 것으로 나타났다. 그러나 노력기대, 사회적 영향, 가격가치, 원격 현존감이 가상 럭셔리 브랜드 제품의 지속적 구매의도에 통계적으로 유의미한 영향을 끼치지 못한 것으로 나타났다. 자가감시성이 가상 럭셔리 브랜드 제품의 지속적 구매 의도에 대한 직접적 영향을 없고 조절효과도 없는 것으로 확인하였다. 마지막은 메타버스 플랫폼 사용자의 가상 럭셔리 브랜드 제품 지속적 구매의도가 실제 럭셔리 브랜드 제품 구매의도에 양향을 미치는 것으로 검증하였다. This study explored the factors that influence users' sustained intention to purchase virtual luxury brand products. To examine the factors, an analysis was conducted based on the UTAUT2 model combining Metaverse platform characteristics of presence (telepresence, self-presence) and consumers’ motivation for virtual luxury brand products (motivation for uniqueness, and motivation for conspicuous consumption). The research method illustrated the moderating effect of self-monitoring as a factor of the user's characteristics. Lastly, the statistics empirically revealed whether or not continuous purchase intention of virtual luxury brand products leads to purchase intention of actual luxury brand products. An online survey was conducted to collect data from the Metaverse platform users who had experience purchasing virtual luxury brand products.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
#  While our daily lives have become convenient due to the development of scientific technology and the generalization of the smartphone, new forms of crimes in the cyber space have become a social issue. Recently, sex crimes subjected to children and teenagers within the metaverse service, which is a new online platform, has increased and become a serious issue. Users create avatars that act in the metaverse space to do games and engage in conversations with other avatars, and as much as individual mutual relationships have become active through these avatars, the existing digital sex crimes have moved and evolved into the metaverse and the children’s and teenagers’ exposure, who are the main users, to sex crime has become more severe. Currently, as the harmful effect and severity regarding the digital sex crimes that occur in the metaverse has been stressed by the National Assembly and Ministry of Justice, they have been recognized as a social issue, and the debate on improvement measures is in progress, and member Kang Seonwoo of the Gender Equality and Family Committee is discussing and establishing the related countermeasure, such as proposing partial the amendment bill for the “Act on Sex Protection on Children and Teenagers” for immediate response and prevention of grooming sex crime subjected to children and teenagers using the metaverse such as the online platform. However, responding to sex crimes that occur in the digital environment that develops rapidly is restricted in terms of the current law, and various systematic problems are revealed, such as the lack of an institution or response measure that manages and controls this problem, while the children and teenager victims are on the rise. This paper intends to present the discussion direction and response measure for digital sex crimes subjected to children and teenagers that occur in the metaverse by analyzing such issues. Chapter 1 explains the background regarding the need for research regarding digital sex crimes subjected to children and teenagers that occur in the metaverse, and Chapter 2 intends to identify the types of metaverse digital sex crimes through organizing characteristics and cases after establishing the concept of metaverse related to research based on previous research. Chapter 3 intends to examine the legislative bill regarding digital sex crime and discuss whether the current law can be applied to the digital sex crimes subjected to children and teenagers that occur in the metaverse. Chapter 4 examines the proposal of the Ministry of Justice and the pending bill in the National Assembly after organizing the issues to be discussed first for application of the current law, and Chapter 5 intends to explain the measures to effectively respond to digital sex crime that occurs in the metaverse by referring to the response measure of the existing digital sex crimes. Chapter 6 intends to present the future direction for legal, institutional, and academic discussion regarding the digital sex crime that occurs in the metaverse.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
#  이에 본 논문에서는 메타버스의 관광산업 활용 사례 및 이슈를 통한 관광산업의 발전 가능성에 관하여 연구하고자 한다. 메타버스와 메타버스 관광에 대한 이론적 고찰과 선행연구, 국내·외 관광산업에서의 메타버스 활용 사례 및 이슈를 조사하고 비교·분석하여 과제 및 개선·보완점을 제시함으로써 메타버스를 활용한 관광산업의 발전에 기여하고자 한다.to the development of the tourism industry using Metaverse by researching and comparing and analyzing the theoretical consideration and prior research on Metaverse and Metaverse tourism, as well as the issues and improvements. 지난 2019년 12월, 전 세계로 퍼지기 시작한 코로나19 바이러스는 우리들의 삶과 각 산업에 큰 변화를 가져왔다. 먼저, 누군가를 서로 대면하여 만나려면 마스크가 필수가 되었고 초·중·고 및 대학교의 수업이나 기업들의 중요한 회의들이 온라인을 통하여 이루어지기도 하였다. 이처럼 우리의 일상에 코로나로 인하여 대면 활동에 큰 제약이 생기며 온택트(Ontact)와 같은 새로운 사회 트랜드가 생겨났고, 이에 따라 시·공간의 제약을 받지 않고 소통이 가능한 가상세계인 ‘메타버스(Metaverse)’가 주목받기 시작하였다.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
#  The results of the study are expected to be used in understanding and strategic design plans for the design and operation of the metaverse educational environment for those who want to use metaverse education.ng on Jinju, the K-entrepreneurship center. After designing a metaverse-based educational environment, In order to improve the educational environment in the process of operating the education, a survey was conducted on experienced entrepreneurship fam tour programs at K University in Gyeongsangnam-do, and an interview survey was conducted by entrepreneurship centers and metaverse experts to design it as an optimal environment.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
#  본 연구를 통하여 메타버스 한류콘텐츠기업의 조직몰입에 상사의 변혁적 리더십, LMX, 직무만족 등이 중요한 영향요인임이 실증되었고 향후 메타버스 한류콘텐츠기업에 긍정적인 방향을 제시하였다.문지를 회수하였고, 불성실한 설문 9부를 제외한 설문지 304부를 분석에 사용하였다. SPSS.v21.0을 사용하여 분석하였으며, 연구 결과는 다음과 같다.-교환관계)와 직무만족을 매개로 하여 조직몰입에 어떠한 영향을 미치는가를 실증하는 것이다.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
#    정신분석비판들의 대체적인 논지는 분석한 주체를 부정하지 않는다. 단지 그 동일시의 본질을 알고, 동일시의 상상적/상징적 효과를 예측하며 쓰자는 것이다. 그러나 지금의 많은 연구들은 색인(index)이나 부호(code) 중심의 가상 인간 매체를 주장하고 있지만 이 색인이나 부호 중심의 주장이 가상공간에서는 단순히 의미의 상징화, 상징적 전환과 등치되면서 기호적 효과만 부각된 감을 지울 수 없다. 본고의 의의는, 가상 정체성의 매체적 성질의 기호적 근거를 통해 정보전달을 지배하던 기존의 매개적 지평을 떠나 라캉의 정신분석학의 타당성을 가늠한 후, 그 사유결과를 다시 현상에서 확인함으로써 가상 정체성 매체에게 단순히 색인과 부호 등 텍스트로서의 도구가 아닌 진정한 탐구의 도구로서 존재의의를 회복시키고자 하는 시도에 있을 것이다. 이는 가상 정체성의 매체적인 의미를 넘어 몰입성의 존재의미까지 확장된다. 왜냐하면 진정한 탐구의 가치는 가상 정체성이 자기 동일시의 재현 문제에 있어서 몰입성을 중심에 두지 않으면 성취할 수 없는 가치이기 때문이다. 본 연구를 통해 ‘가상 정체성 매체화에 관한 연구가, 단순히 기호적 전달이 도구 성질을 내세우는, 그래서 참여자의 자기 소외와 재현을 간과하는 이 현상은 이대로 좋은가’라는 문제의식의 촉발점이 되기를 조심스럽게 기대해 본다.of virtual identity, to assess the validity of Lacan's psychoanalysis, and then to confirm the result of the reasoning in the phenomenon. It will be an attempt to restore the significance of existence to identity media as a tool of true inquiry, not simply as a textual tool such as index and code. This extends beyond the media meaning of virtual identity to the meaning of existence of immersion. Because the value of true exploration is a value that cannot be achieved unless immersion is centered in the problem of representation of self-identification of virtual identity. Through this study, it is carefully hoped that 'a study on the media of virtual identity, a phenomenon in which a simple symbolic transmission emphasizes the instrumental quality, and therefore overlooks the self-alienation and representation of the participants, will become a trigger for a critical mind.' see. 본고는 가상 정체성이 텍스트나 이미지처럼 정보 전달 중심의 매체가 아니라는 점을 논증하고자 한다. 다시 말해 텍스트나 이미지 등 매체의 매개적 지평으로 가상 정체성을 바라볼 수 없다는 뜻이다. 가상 정체성은 가상 정체성에 맞는 매개적 지평을 가져야 한다. 그랬을 때 비로소 가상 정체성은 가상 인간의 가상공간에 물임에 건설적으로 봉사할 수 있다.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
#  언택트 시대가 열리면서 교육현장에는 전통적인 방식의 수업뿐만 아니라 다양한 교육 플랫폼을 활용하는 여러 가지 방식의 수업이 시도되고 있다. 메타버스 플랫폼이 현재 유행하는 이유는 탐험, 소통, 성취의 기쁨에 대한 사람들의 질적 양적 결핍에 기인한다. 메타버스를 포함하는 가상 세계는 이러한 결핍을 해결할 창구이므로 가상 세계는 현대 사회에서 계속 진화하고 발전하고 유행할 것이다. 메타버스를 활용하는 교육은 한시적인 유행에서 그치지 않고 향후에 보편적인 수업 방식의 한 형태로 자리 잡을 것이다. 따라서 이러한 수업 방식에 대한 연구가 지속적으로 필요하다.한 제한사항들이 발견되었다. on this teaching method is continuously needed. 팬데믹 상황을 초래하는 코로나 사태는 전 세계적으로 언택트 시대를 열었고, 이에 따라 원격학습의 영역은 수업 형태의 중심으로 자리잡게 되었다. 이와 같은 학습 형태의 변화는 오프라인 교육의 축소와 온라인 교육의 확장이라는 새로운 교육 패러다임의 전환을 요구하고 있다.rse-based classes as actual classes and confused them with games, showing behaviors that they did not usually do and interfering with classes. Finally, restrictions were found due to the lack of educational equipment in schools
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
# 수집된 결과는 c:\\py_temp\riss.txt 에 저장되었습니다

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time          
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--force-device-scale-factor=1.5")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s, options=chrome_options)

url = 'https://korean.visitkorea.or.kr/main/main.do'
driver.get(url)
time.sleep(3)
driver.maximize_window()
time.sleep(2)

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.XPATH,'//*[@id="inp_search"]')
driver.find_element(By.XPATH,'//*[@id="inp_search"]').click( )
element.send_keys('제주도')
driver.find_element(By.XPATH,'//*[@id="placeHolder"]/a').click( )
time.sleep(2)

#Step 6.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('div','srchResultListW').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

#Step 7. 표준 출력 방향을 바꾸어 txt 파일에 저장하기
import sys 
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\riss.txt): ')

orig_stdout = sys.stdout
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file  #모니터에 출력하지 말고 file 에 출력해라

for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()    
sys.stdout = orig_stdout  #원래대로 변경 - 다시 화면에 출력시켜라    

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 34
#      31 html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
#      32 soup_1 = BeautifulSoup(html_1, 'html.parser')
# ---> 34 content_1 = soup_1.find('div','srchResultListW').find_all('li')
#      35 for i in content_1 :
#      36     print(i.get_text().replace("\n"," ").strip())
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time          
from selenium.webdriver.chrome.options import Options

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://naver.com'
driver.get(url)
time.sleep(3)
driver.maximize_window()
#time.sleep(2)
#Step 4. 자동으로 검색어 입력 후 조회하기
#driver.find_element(By.XPATH, '//*[@id="inp_search"]').click( )
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys('서진수 빅데이터')
element.send_keys('\n')
#driver.find_element(By.XPATH,'//*[@id="placeHolder"]/a').click( )
time.sleep(2)

driver.find_element(By.LINK_TEXT,'뉴스').click() # 링크, 하이퍼링크(메뉴)를 누를 때 사용
time.sleep(2)

#Step 6.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('ul','list_news _infinite_list').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

#Step 7. 표준 출력 방향을 바꾸어 txt 파일에 저장하기
import sys

orig_stdout = sys.stdout
file = open('c:\\py_temp\\naver.txt' , 'a' , encoding='UTF-8')
sys.stdout = file  #모니터에 출력하지 말고 file 에 출력해라

for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()    
sys.stdout = orig_stdout  #원래대로 변경 - 다시 화면에 출력시켜라
# Out:
# 문서 저장하기  Keep에 저장 Keep 바로가기  베타뉴스2018.04.11.   빅데이터 전문가 서진수, '강사양성' 직접 나선다   해당 과정에 대한 내용은 오프라인 설명회에서 공개되며, 참가를 원하는 사람은 19일까지 온오프믹스 홈페이지(KBS 명견만리 서진수 직강 '빅데이터 전문강사 되기' 무료 세미나)를 통해 신청하면 된다. 서진수 대표에 대한 자세한 정보는 포털에 ‘서진수 홈페이지’ 검색 후 확인할 수 있다. [ 경제신문의...
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  중도일보2018.04.10.   빅데이터 전문가 서진수, 4차 산업혁명 시대의 가치와 준비 방법 제시   지난 6일, 성수동 카페에서 진행된 명사와의 인터뷰에서 빅데이터 전문가 서진수 대표가 4차산업혁명과 빅데이터, 미래에 대해 약 4시간 동안 다양한 이야기를 나눴다.Q. 간단하게 본인 소개 부탁 드립니다.A. 저는 고향이 경남 양산입니다. 집안 여건이 좋지 않아서 중학교 정도부터 학교 마치고 방과 후에 집...
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  게임포커스2015.08.10.   '빅데이터 분석 전도사' 서진수 소장 "데이터 분석, 누구나 할 수 있다"   게임포커스는 '빅데이터 분석 전도사'로 잘 알려진 서진수 데이터컨시어지랩 연구소장을 만나 빅데이터, 빅데이터 전문가란 어떤 것인지, 그가 강연 등에서 소개한 데이터 분석 툴 'R'은 어떤 것인지 들어봤다. 데이터앤피플 대표이사이자 데이터컨시어지랩 연구소장으로 재직중인 서진수 소장은 고용노동부...
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  연합뉴스2015.05.20.네이버뉴스   '빅데이터 분석 전도사' 서진수, 무료 강연 진행   ▲도서출판더알음(대표 서진수)은 빅데이터 활용과 관련해 대학교와 대학원, 회사 등에서 무료 지식특강을 진행한다고 20일 밝혔다. 입문자와 초보자를 위한 빅데이터 분석 방법을 다루는 이번 강의는 취업난을 겪고 있는 인문계열 학생들을 위해 기획됐다. 최근 산업 분야에서 주목 받는 기술인 빅데이터는...
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  SBS CNBC2015.05.18.네이버뉴스   빅데이터 전문가 서진수 청년들의 희망 멘토로 강단 서다   저자 서진수는 "빅데이터는 앞으로 산업 분야를 가리지 않고 우리가 사는 미래를 예측할 수 있는 도구가 될 것"이라고 예상하면서 "데이터 분석에 입문하고자 하는 분들이나 현직에서 데이터 관련 업무를 하고 있지만 뭔가 부족한 부분을 느끼는 이들에게 좋은 길잡이가 됐으면 하는 바람"이라고 말했다....
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  뉴시스2015.05.04.네이버뉴스   ‘빅데이터 분석 전도사’ 서진수 주목, 인문대생 멘토   = 데이터 관리와 분석 전문가인 서진수가 빅데이터 활용 무료강연을 펼치고 있다. 그는 데이터 관련 분야에서 15년 정도 종사하면서 다양한 기업체의 데이터베이스를 구축하고 운영, 분석해왔다. 오라클 SQL과 PL/SQL, 오라클 관리실무, 오라클 백업과 복구 등 총 8권의 데이터베이스(오라클) 관련 베스트셀러를...
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  베리타스알파2024.05.29.   세종사이버대 디지털마케팅학과 '빅데이터 활용능력 자격증 대비' 특강...   이날 자격증 특강은 학교에서 '마케터를 위한 인공지능' 수업을 담당하는 서진수 교수가 지도했다. 특히 재학생을 중심으로 보편화되고 있는 빅데이터 활용 능력에 대한 지속적 관심을 반영하고 자격증 취득을 목표로 하는 재학생들이 언제든지 자격증 취득 콘텐츠에 접근할 수 있도록 학과 유튜브 채널에도...    세종사이버대, ‘빅데이터 활용능력 자격증 대비’ 특강  대학저널2024.05.29.   세종사이버대, '빅데이터 활용능력 자격증' 특강 개최  이뉴스투데이2024.05.29.
#
#
# 세종사이버대, ‘빅데이터 활용능력 자격증 대비’ 특강  대학저널2024.05.29.
#
#
# 세종사이버대, '빅데이터 활용능력 자격증' 특강 개최  이뉴스투데이2024.05.29.
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  한국경제TV2023.04.05.네이버뉴스   서진수 세종사이버대 디지털마케팅학과 교수, ‘너 혼자서도 할 수 있어...   세종사이버대학교(총장 신구)는 지난 3월 30일 서진수 디지털마케팅학과 교수가 최근 저서 ‘너 혼자서도 할 수 있어! SQL 능력자’를 출간했다고 5일 밝혔다. 서 교수는 책의 서문을 통해 “ChatGPT와 같이 빅데이터와 인공지능을 활용하는 분야에서 SQL 언어의 능력을 요구하는 이유는 크게 두 가지”라며 “첫...    세종사이버대 디지털마케팅학과 서진수 교수 '너 혼자서도 할 수 있어!...  베리타스알파2023.04.05.   서진수 세종사이버대 디지털마케팅학과 교수, '너 혼자서도 할 수 있어...  교수신문2023.04.05.
#
#
# 세종사이버대 디지털마케팅학과 서진수 교수 '너 혼자서도 할 수 있어!...  베리타스알파2023.04.05.
#
#
# 서진수 세종사이버대 디지털마케팅학과 교수, '너 혼자서도 할 수 있어...  교수신문2023.04.05.
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  뉴스12016.05.10.네이버뉴스   인공지능 시대 개막, 빅데이터 분석 세미나 ‘화제’   ㈜데이터앤피플, ㈜컨시어지소프트의 서진수 대표는 빅데이터와 머신 러닝 관련 분야 전문가로 15년의 경력을 자랑하는 베테랑이다. 서진수 대표는 지식은 널리 퍼질수록 더 가치가 있고 세상을 밝게 할 수 있다는 신념으로 대학교와 대학원·관련 협회와 단체들을 찾아 다니면서 학생과 교수·회사...
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  데일리한국2016.05.02.   알파고 통해 바라본 미래…빅데이터 중요성 확대   빅데이터 전문가 서진수 대표 “빅데이터와 프로그래밍 관련지식이 곧 경쟁력” 세계를 휩쓴 올 상반기 최대의 이슈 가운데 하나는 알파고와 이세돌9단의 대국이었다. 인간과 인공지능의 대결로도 풀이되는 이번 대국은, 진정한 승자가 누구인가에 대한 의견조차 분분했을 정도로 치열한 경합을 보여주며 많은...
