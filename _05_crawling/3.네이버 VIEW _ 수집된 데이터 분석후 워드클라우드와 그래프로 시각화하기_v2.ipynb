# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# 네이버 블로그 정보 수집하여 저장하기

print("=" *80)
print(" 네이버 VIEW - 저장할 내용을 목록으로 만들어서 xls , csv 형식으로 저장하기")
print("=" *80)

#Step 0. 필요한 모듈과 라이브러리를 로딩하고 검색어를 입력 받습니다

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time
import sys        # system 설정을 변경하기 위해 필요합니다
import math
import pandas  as pd   
import os
import openpyxl

query_txt = input('1.크롤링할 키워드는 무엇입니까?: ')
cnt=int(input('2.수집할 데이터는 몇 건입니까?: ') )
page_cnt = math.ceil(cnt / 30)

f_dir = input('3.결과를 저장할 폴더이름을 입력해주세요(기본경로: c:\\py_temp\\) :')
if f_dir =='' :
    f_dir = 'c:\\py_temp\\'
    
#Step 1. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
# import chromedriver_autoinstaller
# chromedriver_autoinstaller.install()
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

driver.get('http://www.naver.com')
time.sleep(5)

#Step 2. 네이버 검색창에 입력 받은 검색어를 넣고 검색한 후 "블로그" 선택
element = driver.find_element(By.ID ,"query")
element.send_keys(query_txt)
element.submit()

# driver.find_element(By.LINK_TEXT,"VIEW").click()
# time.sleep(1)

driver.find_element(By.LINK_TEXT,"블로그").click()
time.sleep(1)

# Step 9. 저장 목록을 만든 후 목록에 있는 내용을 파일에 저장하기

no2 = [ ]           # 게시글 번호 컬럼
title2 = [ ]        # 게시물 제목 컬럼
contents2 = [ ]     # 게시글 내용 컬럼
bdate2 = [ ]        # 작성 일자 컬럼
nick2 = [ ]         # 블로그 닉네임
writer2 =[ ]        # 작성자

#Step 5. 현재 페이지의 내용을 저장 목록을 만든 후 목록에 있는 내용을 파일에 저장하기
# 자동 스크롤다운 함수
def scroll_down(driver):
  driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
  time.sleep(1)

if page_cnt >= 2 :
    i = 1
    while (i < page_cnt + 1):
        scroll_down(driver) 
        i += 1
        print('%s 페이지 정보를 추출하고 있으니 잠시만 기다려 주세요~~^^' %i)

print("\n")

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

view_list = soup.find('ul','lst_view _fe_view_infinite_scroll_append_target').find_all('li')

no = 1

for i in view_list :
    try :
        title = i.find('div','title_area').find('a').get_text( ) 
    except :
        continue
    else :

        no2.append(no)                            # 게시물 번호 리스트에 추가
        print('1.번호:',no)
        #title = all_title[5].get_text( )          # 게시물 제목
        title2.append(title)                      # 게시물 제목 리스트에 추가
        print('2.제목:',title)
    
        writer = i.find('div','user_info').find('a').get_text( ) 
        #writer = all_title[4].get_text( )          # 게시물 작성자
        writer2.append(writer)                      # 게시물 작성자 리스트에 추가
        print('3.작성자:',writer)
    
        
        try :
            contents = i.find('div' , 'dsc_area').get_text( )   # 게시물 내용
        except :
            contents = '본문 요약 내용이 없습니다'
            contents2.append(contents)                # 게시물 내용 리스트에 추가
            print('4.요약내용:',contents)
        else :
            contents2.append(contents)                # 게시물 내용 리스트에 추가
            print('4.요약내용:',contents)
    
        bdate = i.find('span','sub').get_text( )  # 작성일자
        bdate2.append(bdate)                     # 작성일자 리스트에 추가
        print('5.작성일자:',bdate)
    
        print("\n")
    
        if no == cnt :
            break
            
        no += 1

# 출력 결과를 표(데이터 프레임) 형태로 만들기

naver_blog = pd.DataFrame()
naver_blog['번호'] = no2
naver_blog['제목'] = title2
naver_blog['작성자'] = writer2
naver_blog['요약내용'] = contents2
naver_blog['작성일자'] = bdate2

# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

sec_name = 'Naver_View'
os.makedirs(f_dir+s+'-'+query_txt+'-'+sec_name)
os.chdir(f_dir+s+'-'+query_txt+'-'+sec_name)

fc_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.csv'
fx_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.xls'

# csv 형태로 저장하기
naver_blog.to_csv(fc_name,encoding="utf-8-sig",index=False)
print(" csv 파일 저장 경로: %s" %fc_name) 

# 엑셀 형태로 저장하기
import openpyxl
naver_blog.to_excel(fx_name , index=False, engine='openpyxl')
print(" xls 파일 저장 경로: %s" %fx_name) 

# 엑셀파일 실행하기
import win32com.client as win32   #pywin32 , pypiwin32 설치후 동작
import win32api  #파이썬 프롬프트를 관리자 권한으로 실행해야 에러없음
                 #파이썬 쉘을 관리자 권한으로 실행한 후 불러오기로 이 소스 실행하기

excel = win32.Dispatch('Excel.Application')
wb = excel.Workbooks.Open(fx_name)
sheet = wb.ActiveSheet
excel.ActiveWorkbook.Save()
excel.Visible=True

driver.close( )
# Out:
# ================================================================================
#  네이버 VIEW - 저장할 내용을 목록으로 만들어서 xls , csv 형식으로 저장하기
# ================================================================================
#
#
# 1.번호: 1
# 2.제목: 제주도 동백꽃 명소 서귀포 제주 동백수목원 입장료
# 3.작성자: 달콤살벌허니
# 4.요약내용:  제주도 동백꽃 명소 서귀포 제주 동백수목원 입장료 올해 첫 여행으로 제주도 다녀왔어요. 시즌이 시즌인지라 제주도 동백꽃 명소 서귀포 몇 군데 다녀왔는데 그중에 가장 먼저 방문한곳 소개해 드릴게요. 유명한 곳 중에서 그나마 상태가 가장 좋았던 곳으로 11월 ~ 2월까지 볼 수 있다고 생각했는데 생각보다 빨리 시즌 오프 해서 당황스럽기까지 했습니다. 제주...
# 5.작성일자: 4주 전
#
#
# 1.번호: 2
# 2.제목: 제주도 함덕 가볼만한곳 함덕 서우봉 둘레길 해변
# 3.작성자: 트래블룸
# 4.요약내용:  제주도 함덕 가볼만한곳 함덕 서우봉 둘레길 해변 안녕하세요. 시원한 함덕 해변 한눈에 내려다볼 수 있는 서우봉에 올라갔다 왔어요. 상쾌한 바람도 맞고 곧 노란 유채꽃이 필 파종지 위치까지 탐색하고 왔답니다. ↓↓ 함덕 서우봉 주소_제주 함덕리 169-3 주차_가능 제주도 동쪽으로 여행할 때 자주 방문하는 함덕. 이날은 시간 여유가 있어서 함덕 서우봉도 걷고 왔어요....
# 5.작성일자: 3일 전
#
#
# 1.번호: 3
# 2.제목: 제주 시내 가볼만한곳 관덕정 제주목관아 제주도 시내 관광지
# 3.작성자: 초록바다 최양훈
# 4.요약내용:  제주 시내 가볼만한곳 관덕정 제주목관아 제주도 시내 관광지 글 &사진 : 초록바다 최양훈 / 여행일 : 2025. 1. 19 제주공항에서 동쪽으로 5.2km떨어진 거리에 제주의 역사와 문화가 살아 숨쉬는 곳이 자리한다. 바로 제주시 가볼만한곳 관덕정과 제주목관아이다. 제주도 여행을 그렇게 많이 드나들었는데 이번에 처음으로 들려보았다. 공항과 거리도 가깝고 볼거리가 제주도...
# 5.작성일자: 5일 전
#
#
# 1.번호: 4
# 2.제목: 제주도 애월 여행 제주 애월카페거리 카페 서쪽 가볼만한곳 여전히 좋네
# 3.작성자: 하벨
# 4.요약내용:  제주도 애월 여행, 서쪽 가볼만한곳 제주 애월카페거리 여행 인플루언서 @하벨 제주도 여행을 하면서 서쪽 코스는 필수로 가야 하는 곳이 되었는데요. 해안선을 따라 드라이브하기도 좋고, 애매랄드빛 해변도 많기 때문이에요. 특히 산책로를 따라 이어진 애월카페거리에서 바라본 오션뷰가 절경이죠. 그럼 제가 다녀온 곳과 함께 제주도 서쪽 가볼만한곳 소개해 볼게요...
# 5.작성일자: 5일 전
#
#
# 1.번호: 5
# 2.제목: 제주 감귤체험 서귀포 제주도 카페 제주 귤따기체험
# 3.작성자: 열씨미
# 4.요약내용:  제주도 카페에서 힐링하고 서귀포 감귤체험 하며 무한시식 하고~ 제주도 여행을 가게 되면 10월부터 다음해 3월까지 제주 감귤체험을 할 수 있어 흥미로웠어요. 가을초에는 풋귤을 따서 청귤을 담고 10월말부터는 제주 귤따기체험을 비롯 한라봉 따기 체험을 할 수 있어요.~열씨미~ 서귀포 대정읍 추사로에는 '어린왕자 감귤밭' 명패를 달고 있는 제주도 카페가 있어요. 1인...
# 5.작성일자: 3주 전
#
#
# 1.번호: 6
# 2.제목: 제주도 추천코스 서귀포 용머리해안 입장시간과 포토존
# 3.작성자: 찌뽕&나뽕이 세상
# 4.요약내용:  제주도를 동서 혹은 남북으로 한쪽으로만 둘러보신다면 선택과 집중이 필요하겠지요 서쪽 그리고 남쪽으로 결정하셨다면 추천코스로 바로 여기! 소개해 봅니다 하늘이 허락한 비경! 꼭... 제주도 추천코스 용머리해안 포토존 사실 발이 가는 곳마다 포토존이 된답니다 대신 조심조심 이동해서 자리 잡고 사진 찍으세요 산방산을 뒤로하고 찍는 여기! 모두가 줄 서서 사진...
# 5.작성일자: 1일 전
#
#
# 1.번호: 7
# 2.제목: 제주도 오일장 제주 5일장 제주 민속오일장 시간 날짜 제주도 시장 구경
# 3.작성자: 클로이
# 4.요약내용:  제주도 오일장 제주 5일장 제주 민속오일장 시간 날짜 제주도 시장 구경 제주여행 중에 날짜만 맞는다면 제주도 오일장 구경 한번 해보시면 어떨까요? 어느 지역이든 여행 가면 그곳의 유명한 재래시장 구경하며 시간 보내는데 참 재미있더라고요 사람들 사는 구경 시장 구경하다 보면 어느새 시간 가는 줄도 모른답니다 제주 5일장 중에서도 제주시에 위치한 제주...
# 5.작성일자: 2주 전
#
#
# 1.번호: 8
# 2.제목: 2월 제주도 여행 제주 동백꽃 명소 6곳!
# 3.작성자: 제주린아
# 4.요약내용:  2월 제주도 여행 제주 동백꽃 명소 모음 평소 제주도 동백꽃 개화시기를 생각해 보면 11월 말부터 1월 말까지로 2월인 지금은 예쁜 스팟을 찾기 힘든데요. 올해 겨울이 한 달 늦게 찾아와서 2월 제주도 여행에서도 제주 동백꽃 명소를 찾아다니면서 꽃구경 실컷 하고 인생샷도 원 없이 남길 수 있답니다. 남원읍 집중코스로 알려드릴게요. #2월제주도여행 #제주동백꽃명소...
# 5.작성일자: 2주 전
#
#
# 1.번호: 9
# 2.제목: 제주도 함덕 가볼만한곳 함덕 해수욕장 제주 해변 드라이브 추천
# 3.작성자: 그루터기
# 4.요약내용:  제주도 함덕 가볼만한곳 함덕 해수욕장 제주 해변 드라이브 추천 글, 사진 : 그루터기 제주 바다는 어디든 좋지만 특히 제주도 함덕 해수욕장을 좋아한다. 제주도 함덕 서우봉 해변이라고도 불리는 이곳은 코발트빛의 아름다운 물빛과 넓은 바다, 바로 옆에 서우봉 산책로와 주변에 편의시설도 잘 되어있는 제주 해변이다. 지난 여행에서 제주 함덕 해수욕장 산책을 하며...
# 5.작성일자: 1주 전
#
#
# 1.번호: 10
# 2.제목: 휘닉스아일랜드 로얄 제주 동쪽 숙소 제주도 리조트 추천 위치
# 3.작성자: 역쟁이
# 4.요약내용:  휘닉스아일랜드 로얄 제주 동쪽 숙소 제주도 리조트 추천 위치 제주도에서 특별한 숙소를 찾는다면 오늘 소개하는 제주도 리조트 휘닉스아일랜드도 그중 한곳이 될 곳이에요. 휘닉스아일랜드는 제주 동쪽에 위치하고 있는데요, 주변에 섭지코지, 성산일출봉, 아쿠아플라넷 제주 등 제주도 여행지가 모두 가까운 데 있어서 제주 동쪽 여행을 하고 나서 찾기에도...
# 5.작성일자: 2일 전
#
#
# 1.번호: 11
# 2.제목: 새해 가볼만한곳, 국내여행지 호캉스 호텔 숙소추천 (서울 부산 제주도)
# 3.작성자: 라파네 포스트
# 4.요약내용:  새해맞이 부산호텔추천 TOP3는파라다이스, 롯데호텔, 아난티 앳 부산 코브 여유롭고 아름다운 자연 경관을 자랑하는 대한민국의 대표적인 휴양지로푸른 바다와 드넓은 초원이 어우러져독특한 풍경을 선사하며 이국적인 분위기 속에서 힐링과 휴식을 즐기기에 완벽한 곳인 제주도숙소!새해 제주호텔추천으로 골라본 TOP3는~해비치호텔, 스위트호텔...
# 5.작성일자: 2025.01.10.
#
#
# 1.번호: 12
# 2.제목: 제주도 2박3일 여행 코스 제주 서쪽 여행 추천
# 3.작성자: 사진여행트래블러제이
# 4.요약내용:  주말을 이용하여, 제주도 2박3일 여행 코스를 계획한다면 제주시와 서쪽 여행을 추천하는게 좋습니다. 공항에서 멀리 않은 곳들을 일정에 넣는다면 더욱 알차게 여행할 수 있어요. 그래서 온늘은 제주도 서쪽 여행 코스로 들리기 좋은 곳들을 소개하려합니다. 아이와 같이 가족여행으로 방문하기 좋은 곳들이니, 참고하시길 바랄께요. 어린왕자 감귤밭 운영시간 09:30~20:00...
# 5.작성일자: 3시간 전
#
#
# 1.번호: 13
# 2.제목: 2월 제주 용머리해안 제주도 서쪽 산방산 가볼만한곳
# 3.작성자: 센루크
# 4.요약내용:  2월 제주 용머리해안 제주도 서쪽 산방산 가볼만한곳 글, 사진 @센루크 2월 제주도 가볼만한곳으로 제주 용머리해안 예전부터 귀동냥으로 들었던 곳! 드디어 이번 제주여행에 다녀왔답니다. 제주도 용머리해안은 산방산 가볼만한곳으로 기대하지 않은 유채꽃도 활짝 피어 관람 시작부터 유쾌하게 만들었어요. 기대이상의 사암층 해안절벽 풍경 유구한 세월의 흔적이...
# 5.작성일자: 2주 전
#
#
# 1.번호: 14
# 2.제목: 제주도 수영장 리조트 따듯한 애월 숙소 제주 누에베
# 3.작성자: 종이배
# 4.요약내용:  제주도 수영장 리조트 따듯한 애월 숙소 제주 누에베 무급사원 제주도여행이야기 2025.01. 애월 숙소로 호캉스를 할 수 있는 제주 누에베풀빌라리조트를 예약했다. 야외 온수풀 수영장도 있어서 사계절 모두 수영이 가능하고, 석식 및 조식도 이용 할 수 있어서 퇴실하고 싶지 않았기에 제주리조트에서 호캉스 제대로 즐기고왔다. 누에베풀빌라&리조트 입실 15:00, 퇴실 11:00...
# 5.작성일자: 2주 전
#
#
# 1.번호: 15
# 2.제목: 제주도 가족 독채 펜션 서귀포 6명 숙소 스테이빌레하임
# 3.작성자: 제주단비의 삶은 여행
# 4.요약내용:  제주도 가족 독채 펜션 서귀포 6명 숙소 스테이빌레하임 글/사진 JEJUDANBY 방문일 2025. 2. 5. 6인 숙박 가능한 제주도 가족 독채 펜션 귤 밭 뷰의 감성 가득한 숙소 반신욕, 자쿠지, 바비큐 무료 구석구석 편안한 내 집 같은 공간 제주도 가족 독채 펜션 서귀포 6명 숙소 스테이빌레하임 지난 5일 부모님과 함께 서귀포 여행을 다녀왔는데요. 감성과 힐링 두 마리 토끼 다...
# 5.작성일자: 6일 전
#
#
#  csv 파일 저장 경로: c:\py_temp\2025-02-14-15-39-42-제주도-Naver_View\2025-02-14-15-39-42-제주도-Naver_View.csv
#  xls 파일 저장 경로: c:\py_temp\2025-02-14-15-39-42-제주도-Naver_View\2025-02-14-15-39-42-제주도-Naver_View.xls

# %%
#Lesson 3.국내 여행 키워드 분석
#Step 1. 필요한 모듈을 실행합니다.

from konlpy.tag import *        #pip install konlpy 먼저 하세요
import matplotlib.pyplot as plt #pip install matplotlib 먼저 하세요
from matplotlib import font_manager , rc
from wordcloud import WordCloud  # pip install wordcloud 먼저 하세요
from collections import Counter
import pandas as pd

okt = Okt()
kkma = Kkma( )

#Step 2 . 텍스트 파일을 불러와서 형태소 분석을 합니다.
data1 = open(fc_name,encoding="UTF-8").read( )
data1 = contents2

#print(data1)
print("\n")

#Step 3. 키워드를 추출합니다
data2=[]
for a in data1 :
    data2.append( okt.nouns(a) )

#Step 4. 추출된 단어들의 빈도를 조사한 후 많이 언급된 100개만 출력합니다
print("\n")
data3 = sum(data2, [])
data4 = Counter(data3)
data5 = data4.most_common(100)

#Step 5. 불용어 제거하기
#sword = open("c:\\py_temp\\여행gsub.txt",encoding='utf-8').read()

#data6 = [ each_word for each_word in data3
#          if each_word not in sword ]

#용어 정리하기
data6 = data5
data6_1 = [ ]
for i in data6 :
    if len(i) >= 2 and len(i) <= 10 :
        if i == '제주' or i == '제주도' or i=='우도' or i =='애월' :
            data6_1.append(i.replace(i,'제주도'))         
        elif i == '국내' or i == '대한민국' or i == '한국' :
            data6_1.append(i.replace(i,'국내여행'))
        elif i == '핑크' or i == '뮬리' or i == '핑크뮬리' :
            data6_1.append(i.replace(i,'핑크뮬리'))
        elif i == '아이' or i == '어린이' or i == '아기' or i =='키즈':
            data6_1.append(i.replace(i,'아이'))
        elif i == '엘리' or i == '시안' or i == '강촌':
            data6_1.append(i.replace(i,'강촌엘리시안'))
        else :
                data6_1.append(i)

            
#Step 6. 글자수로 불용어 제거하기
data7 = []
for i in data6_1 :
    if len(i) >= 2 and len(i) <= 10 :
        data7.append(i) 
print('키워드 추출 완료')
# Out:
# 키워드 추출 완료

# %%
# Step 7. 단어별 빈도수 집계하기
data8 = Counter(data7)
data9 = data8.most_common(200)
print("2.단어별 빈도수:",data9)
data10 = dict(data9)
# Out:
# 2.단어별 빈도수: [(('제주도', 39), 1), (('제주', 27), 1), (('곳', 25), 1), (('여행', 22), 1), (('함덕', 12), 1), (('수', 8), 1), (('서귀포', 7), 1), (('서쪽', 7), 1), (('추천', 7), 1), (('숙소', 7), 1), (('서우', 6), 1), (('봉', 6), 1), (('해변', 6), 1), (('사진', 6), 1), (('코스', 6), 1), (('구경', 6), 1), (('리조트', 6), 1), (('동백꽃', 5), 1), (('소개', 5), 1), (('동쪽', 5), 1), (('시간', 5), 1), (('애월', 5), 1), (('호텔', 5), 1), (('명소', 4), 1), (('중', 4), 1), (('방문', 4), 1), (('위치', 4), 1), (('글', 4), 1), (('바다', 4), 1), (('거리', 4), 1), (('카페', 4), 1), (('감귤', 4), 1), (('체험', 4), 1), (('용머리', 4), 1), (('가족', 4), 1), (('시즌', 3), 1), (('생각', 3), 1), (('공항', 3), 1), (('바로', 3), 1), (('제주시', 3), 1), (('인', 3), 1), (('힐링', 3), 1), (('밭', 3), 1), (('산방산', 3), 1), (('모두', 3), 1), (('오일장', 3), 1), (('해수욕장', 3), 1), (('휘닉스', 3), 1), (('아일랜드', 3), 1), (('누에', 3), 1), (('독채', 3), 1), (('펜션', 3), 1), (('올해', 2), 1), (('가장', 2), 1), (('유채꽃', 2), 1), (('여유', 2), 1), (('시내', 2), 1), (('관덕정', 2), 1), (('일', 2), 1), (('자리', 2), 1), (('이번', 2), 1), (('드라이브', 2), 1), (('산책로', 2), 1), (('뷰', 2), 1), (('귤', 2), 1), (('어린왕자', 2), 1), (('달', 2), 1), (('집중', 2), 1), (('여기', 2), 1), (('포토', 2), 1), (('존', 2), 1), (('줄', 2), 1), (('날짜', 2), 1), (('시장', 2), 1), (('말', 2), 1), (('찾기', 2), 1), (('주변', 2), 1), (('지난', 2), 1), (('새해', 2), 1), (('부산', 2), 1), (('풍경', 2), 1), (('이용', 2), 1), (('수영장', 2), 1), (('호캉스', 2), 1), (('빌라', 2), 1), (('명', 2), 1), (('스테이', 2), 1), (('빌레', 2), 1), (('하임', 2), 1), (('감성', 2), 1), (('동백', 1), 1), (('수목원', 1), 1), (('입장료', 1), 1), (('첫', 1), 1), (('인지', 1), 1), (('몇', 1), 1), (('군데', 1), 1), (('먼저', 1), 1), (('상태', 1), 1), (('볼', 1), 1)]

# %%
# 데이터 프레임으로 변환하여 저장하기
data9_2 = pd.DataFrame(data9)
data9_3 = data9_2.rename(columns={0:'키워드' , 1:'빈도수'})
display(data9_3)
data9_3.to_csv('c:\\py_temp\\여행주요키워드.csv' , index=False , encoding='utf-8-sig')
data9_10 = data9_3.head(10)
display(data9_10)
# Out:
#           키워드  빈도수
# 0   (제주도, 39)    1
# 1    (제주, 27)    1
# 2     (곳, 25)    1
# 3    (여행, 22)    1
# 4    (함덕, 12)    1
# ..        ...  ...
# 95     (몇, 1)    1
# 96    (군데, 1)    1
# 97    (먼저, 1)    1
# 98    (상태, 1)    1
# 99     (볼, 1)    1
#
# [100 rows x 2 columns]
#          키워드  빈도수
# 0  (제주도, 39)    1
# 1   (제주, 27)    1
# 2    (곳, 25)    1
# 3   (여행, 22)    1
# 4   (함덕, 12)    1
# 5     (수, 8)    1
# 6   (서귀포, 7)    1
# 7    (서쪽, 7)    1
# 8    (추천, 7)    1
# 9    (숙소, 7)    1

# %%
#바 차트 그리기 - 상위 10군데만
from matplotlib import pyplot as plt 
import matplotlib.font_manager as fm
import matplotlib
import numpy as np

font_location = "C:\\Windows\\Fonts\\malgun.ttf"
font_name = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font' , family=font_name)
plt.style.use('ggplot')
plt.figure(figsize=(10,6))

x = data9_10['키워드']
y = data9_10['빈도수']

colors = [np.random.rand(3,) for _ in data9_10['키워드']]

plt.bar(x,y , color = colors , width=0.5)
plt.title('여행 관련 주요 키워드 Top 10')
plt.ylabel('빈도수(단위:건)')
plt.xlabel('키워드')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 18
#      14 y = data9_10['빈도수']
#      16 colors = [np.random.rand(3,) for _ in data9_10['키워드']]
# ---> 18 plt.bar(x,y , color = colors , width=0.5)
#      19 plt.title('여행 관련 주요 키워드 Top 10')
#      20 plt.ylabel('빈도수(단위:건)')
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
#    2962         **({"data": data} if data is not None else {}),
#    2963         **kwargs,
#    2964     )
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2492, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2486         x = 0
#    2488 if orientation == 'vertical':
#    2489     # It is possible for y (bottom) to contain unit information.
#    2490     # However, it is also possible for y=0 for the default and height
#    2491     # to contain unit information.  This will prioritize the units of y.
# -> 2492     self._process_unit_info(
#    2493         [("x", x), ("y", y), ("y", height)], kwargs, convert=False)
#    2494     if log:
#    2495         self.set_yscale('log', nonpositive='clip')
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:2585, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2583     # Update from data if axis is already set but no unit is set yet.
#    2584     if axis is not None and data is not None and not axis.have_units():
# -> 2585         axis.update_units(data)
#    2586 for axis_name, axis in axis_map.items():
#    2587     # Return if no axis is set.
#    2588     if axis is None:
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\matplotlib\axis.py:1756, in Axis.update_units(self, data)
#    1754 neednew = self.converter != converter
#    1755 self.converter = converter
# -> 1756 default = self.converter.default_units(data, self)
#    1757 if default is not None and self.units is None:
#    1758     self.set_units(default)
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\matplotlib\category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\matplotlib\category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     213 convertible = True
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#     219         convertible = self._str_is_convertible(val)
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:91, in check_isinstance(types, **kwargs)
#      89     names.remove("None")
#      90     names.append("None")
# ---> 91 raise TypeError(
#      92     "{!r} must be an instance of {}, not a {}".format(
#      93         k,
#      94         ", ".join(names[:-1]) + " or " + names[-1]
#      95         if len(names) > 1 else names[0],
#      96         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a tuple

# %%
#Step 8. 워드 클라우드 그리기
wordcloud = WordCloud(font_path="c:\\windows\\fonts\\H2MKPB.TTF" ,
                       relative_scaling=0.4,
                       background_color="white"
                     ).generate_from_frequencies(data10)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[10], line 5
#       1 #Step 8. 워드 클라우드 그리기
#       2 wordcloud = WordCloud(font_path="c:\\windows\\fonts\\H2MKPB.TTF" ,
#       3                        relative_scaling=0.4,
#       4                        background_color="white"
# ----> 5                      ).generate_from_frequencies(data10)
#       6 plt.figure(figsize=(10,8))
#       7 plt.imshow(wordcloud)
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:453, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     451     font_size = self.height
#     452 else:
# --> 453     self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                    max_font_size=self.height)
#     455     # find font sizes
#     456     sizes = [x[1] for x in self.layout_]
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:511, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     508 transposed_font = ImageFont.TransposedFont(
#     509     font, orientation=orientation)
#     510 # get size of resulting text
# --> 511 box_size = draw.textbbox((0, 0), word, font=transposed_font, anchor="lt")
#     512 # find possible places using integral image:
#     513 result = occupancy.sample_position(box_size[3] + self.margin,
#     514                                    box_size[2] + self.margin,
#     515                                    random_state)
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\PIL\ImageDraw.py:859, in ImageDraw.textbbox(self, xy, text, font, anchor, spacing, align, direction, features, language, stroke_width, embedded_color, font_size)
#     844     return self.multiline_textbbox(
#     845         xy,
#     846         text,
#    (...)
#     855         embedded_color,
#     856     )
#     858 mode = "RGBA" if embedded_color else self.fontmode
# --> 859 bbox = font.getbbox(
#     860     text, mode, direction, features, language, stroke_width, anchor
#     861 )
#     862 return bbox[0] + xy[0], bbox[1] + xy[1], bbox[2] + xy[0], bbox[3] + xy[1]
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\PIL\ImageFont.py:730, in TransposedFont.getbbox(self, text, *args, **kwargs)
#     727 def getbbox(self, text, *args, **kwargs):
#     728     # TransposedFont doesn't support getmask2, move top-left point to (0, 0)
#     729     # this has no effect on ImageFont and simulates anchor="lt" for FreeTypeFont
# --> 730     left, top, right, bottom = self.font.getbbox(text, *args, **kwargs)
#     731     width = right - left
#     732     height = bottom - top
#
# File c:\Users\ajhaj\anaconda3\Lib\site-packages\PIL\ImageFont.py:418, in FreeTypeFont.getbbox(self, text, mode, direction, features, language, stroke_width, anchor)
#     369 """
#     370 Returns bounding box (in pixels) of given text relative to given anchor
#     371 when rendered in font with provided direction, features, and language.
#    (...)
#     415 :return: ``(left, top, right, bottom)`` bounding box
#     416 """
#     417 _string_length_check(text)
# --> 418 size, offset = self.font.getsize(
#     419     text, mode, direction, features, language, anchor
#     420 )
#     421 left, top = offset[0] - stroke_width, offset[1] - stroke_width
#     422 width, height = size[0] + 2 * stroke_width, size[1] + 2 * stroke_width
#
# MemoryError: PyMem_New() failed

# %%
import numpy as np         # pip install numpy
from PIL import Image      # pip install Image
from wordcloud import ImageColorGenerator
korea = np.array(Image.open("c:\\py_temp\\images\\heart.jpg"))
wc = WordCloud(font_path="c:\\windows\\fonts\\H2MKPB.TTF" ,
                       relative_scaling=0.2,mask = korea,
                       background_color="white",
                       min_font_size=1,
                       max_font_size=50,
                       max_words=5000
                     ).generate_from_frequencies(data10)
plt.figure(figsize=(8,8))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
korea = np.array(Image.open("c:\\py_temp\\images\\korea.jpg"))
wc = WordCloud(font_path="c:\\windows\\fonts\\H2MKPB.TTF" ,
                       relative_scaling=0.2,mask = korea,
                       background_color="white",
                       min_font_size=1,
                       max_font_size=50,
                       max_words=5000
                     ).generate_from_frequencies(data10)
plt.figure(figsize=(5,7))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
korea = np.array(Image.open("c:\\py_temp\\images\\star.png"))
wc = WordCloud(font_path="c:\\windows\\fonts\\H2MKPB.TTF" ,
                       relative_scaling=0.2,mask = korea,
                       background_color="white",
                       min_font_size=1,
                       max_font_size=50,
                       max_words=5000
                     ).generate_from_frequencies(data10)
plt.figure(figsize=(10,8))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
korea = np.array(Image.open("c:\\py_temp\\images\\samsung.jpg"))
wc = WordCloud(font_path="c:\\windows\\fonts\\H2MKPB.TTF" ,
                       relative_scaling=0.2,mask = korea,
                       background_color="white",
                       min_font_size=1,
                       max_font_size=100,
                       max_words=5000
                     ).generate_from_frequencies(data10)
plt.figure(figsize=(10,8))
plt.imshow(wc)
plt.axis('off')
plt.show()
